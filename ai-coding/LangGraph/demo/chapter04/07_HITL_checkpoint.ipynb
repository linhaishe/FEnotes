# %%
from typing import TypedDict

from langgraph.graph import StateGraph, START, END
from langgraph.types import Command, interrupt
from langgraph.checkpoint.memory import InMemorySaver

class OverAllState(TypedDict):
    username: str
    age: int

def node_a(state: OverAllState) -> OverAllState:
    username = interrupt("请输入您的姓名")
    age = interrupt("请输入您的年龄")
    return {
        "username": username,
        "age": age
    }

builder = StateGraph(state_schema=OverAllState)
builder.add_node("node_a", node_a)
builder.add_edge(START, "node_a")
builder.add_edge("node_a", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

config = {"configurable": {"thread_id": "123"}}
username_interrupted_res = graph.invoke({}, config=config)
print('=' * 30, '-> username_interrupted_res <-', '=' * 30)
print(username_interrupted_res)
# Out:
# ============================== -> username_interrupted_res <- ==============================
# {'__interrupt__': [Interrupt(value='请输入您的姓名', id='57fe6ed5c191e3656aff19e4df57a6b0')]}

# %%
username_interrupted_his = list(graph.get_state_history(config=config))
print('=' * 30, '-> username_interrupted_his <-', '=' * 30)
print(username_interrupted_his)
# Out:
# ============================== -> username_interrupted_his <- ==============================
# [StateSnapshot(values={}, next=('node_a',), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c42a-ff8b-6e90-8000-7b87b1a09af5'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-10T09:35:28.719622+00:00', parent_config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c42a-ff8a-6495-bfff-0c7b31c8bb17'}}, tasks=(PregelTask(id='0ffd100b-d3bc-bade-fcc2-0e025b41a694', name='node_a', path=('__pregel_pull', 'node_a'), error=None, interrupts=(Interrupt(value='请输入您的姓名', id='57fe6ed5c191e3656aff19e4df57a6b0'),), state=None, result=None),), interrupts=(Interrupt(value='请输入您的姓名', id='57fe6ed5c191e3656aff19e4df57a6b0'),)), StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c42a-ff8a-6495-bfff-0c7b31c8bb17'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-10T09:35:28.718959+00:00', parent_config=None, tasks=(PregelTask(id='89861eee-6cd0-d9d1-e7b2-4d9971040463', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={}),), interrupts=())]

# %%
age_interrupted_res = graph.invoke(Command(resume="小黄"), config=config)
print('=' * 30, '-> age_interrupted_res <-', '=' * 30)
print(age_interrupted_res)
# Out:
# ============================== -> age_interrupted_res <- ==============================
# {'__interrupt__': [Interrupt(value='请输入您的年龄', id='57fe6ed5c191e3656aff19e4df57a6b0')]}

# %%
age_interrupted_his = list(graph.get_state_history(config=config))
print('=' * 30, '-> age_interrupted_his <-', '=' * 30)
print(age_interrupted_his)
# Out:
# ============================== -> age_interrupted_his <- ==============================
# [StateSnapshot(values={}, next=('node_a',), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c42a-ff8b-6e90-8000-7b87b1a09af5'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-10T09:35:28.719622+00:00', parent_config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c42a-ff8a-6495-bfff-0c7b31c8bb17'}}, tasks=(PregelTask(id='0ffd100b-d3bc-bade-fcc2-0e025b41a694', name='node_a', path=('__pregel_pull', 'node_a'), error=None, interrupts=(Interrupt(value='请输入您的年龄', id='57fe6ed5c191e3656aff19e4df57a6b0'),), state=None, result={}),), interrupts=(Interrupt(value='请输入您的年龄', id='57fe6ed5c191e3656aff19e4df57a6b0'),)), StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c42a-ff8a-6495-bfff-0c7b31c8bb17'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-10T09:35:28.718959+00:00', parent_config=None, tasks=(PregelTask(id='89861eee-6cd0-d9d1-e7b2-4d9971040463', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={}),), interrupts=())]

# %%
resumed_res = graph.invoke(Command(resume=123), config=config)
print('=' * 30, '-> resumed_res <-', '=' * 30)
print(resumed_res)
# Out:
# ============================== -> resumed_res <- ==============================
# {'username': '小黄', 'age': 123}

# %%
resumed_his = list(graph.get_state_history(config=config))
print('=' * 30, '-> resumed_his <-', '=' * 30)
print(resumed_his)
# Out:
# ============================== -> resumed_his <- ==============================
# [StateSnapshot(values={'username': '小黄', 'age': 123}, next=(), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c436-974f-6f94-8001-25940f6843dc'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-10T09:40:39.912416+00:00', parent_config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c42a-ff8b-6e90-8000-7b87b1a09af5'}}, tasks=(), interrupts=()), StateSnapshot(values={}, next=('node_a',), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c42a-ff8b-6e90-8000-7b87b1a09af5'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-10T09:35:28.719622+00:00', parent_config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c42a-ff8a-6495-bfff-0c7b31c8bb17'}}, tasks=(PregelTask(id='0ffd100b-d3bc-bade-fcc2-0e025b41a694', name='node_a', path=('__pregel_pull', 'node_a'), error=None, interrupts=(Interrupt(value='请输入您的年龄', id='57fe6ed5c191e3656aff19e4df57a6b0'),), state=None, result={'username': '小黄', 'age': 123}),), interrupts=(Interrupt(value='请输入您的年龄', id='57fe6ed5c191e3656aff19e4df57a6b0'),)), StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '123', 'checkpoint_ns': '', 'checkpoint_id': '1f17c42a-ff8a-6495-bfff-0c7b31c8bb17'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-10T09:35:28.718959+00:00', parent_config=None, tasks=(PregelTask(id='89861eee-6cd0-d9d1-e7b2-4d9971040463', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={}),), interrupts=())]
