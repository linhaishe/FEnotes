# %%
from langgraph.store.postgres import PostgresStore
from typing import Final,Tuple

DB_URL = "postgresql://langgraph_user:123456@localhost:5432/langgraph_db?sslmode=disable"

with PostgresStore.from_conn_string(DB_URL) as store:
    #1. 创建长期记忆存储的表格
    store.setup()
    #2. 构建永久记忆数据
    #2.1 构建命名空间
    USERS_NS:Final[Tuple[str]] = ("users",)
    PREFERENCES_KEY:Final[str] = "preferences"

    namespace1 = (*USERS_NS,"Alice")
    namespace2 = (*USERS_NS,"Bob")
    namespace3 = (*USERS_NS,"Black")

    value1 = {
        "course":"计算机组成原理",
        "sports":"跑步",
        "food":"紫光园奶皮子酸奶"
    }

    value2 = {
        "course": "数字电路与模拟电路",
        "sports": "跑步",
        "food": "奶皮子糖葫芦"
    }

    value3 = {
        "course": "数字电路与模拟电路",
        "sports": "羽毛球",
        "food": "紫光园奶皮子酸奶"
    }

    #3. 写入永久记忆数据
    store.put(namespace1,PREFERENCES_KEY,value1)
    store.put(namespace2,PREFERENCES_KEY,value2)
    store.put(namespace3,PREFERENCES_KEY,value3)

    for item in store.search(USERS_NS):
        print(item)
# Out:
# Item(namespace=['users', 'Black'], key='preferences', value={'food': '紫光园奶皮子酸奶', 'course': '数字电路与模拟电路', 'sports': '羽毛球'}, created_at='2026-07-09T12:02:08.994560+08:00', updated_at='2026-07-09T14:50:06.575525+08:00', score=None)
# Item(namespace=['users', 'Bob'], key='preferences', value={'food': '奶皮子糖葫芦', 'course': '数字电路与模拟电路', 'sports': '跑步'}, created_at='2026-07-09T12:02:08.994224+08:00', updated_at='2026-07-09T14:50:06.575090+08:00', score=None)
# Item(namespace=['users', 'Alice'], key='preferences', value={'food': '紫光园奶皮子酸奶', 'course': '计算机组成原理', 'sports': '跑步'}, created_at='2026-07-09T12:02:08.989782+08:00', updated_at='2026-07-09T14:50:06.573588+08:00', score=None)

# %%
from typing import TypedDict, Annotated, Literal

from dotenv import  load_dotenv
from langchain_core.messages import SystemMessage,HumanMessage, AIMessage, ToolMessage
from langchain_deepseek import ChatDeepSeek
from langgraph.graph import StateGraph,START,END
from langgraph.runtime import Runtime
from loguru import logger
from langgraph.checkpoint.postgres import  PostgresSaver
from langgraph.graph.message import MessagesState

load_dotenv(override=True)

model = ChatDeepSeek(
    model = "deepseek-v4-flash",
    extra_body={
        "thinking":{
            "type":"disabled"
        }
    }
)

#1. 声明全局状态
class OverAllState(MessagesState):
    username:str
    user_input:str
    output:str
    preferences:dict[str,str]

#2. 声明节点
#2.1 路由函数 如果状态中没有用户偏好 则从长期记忆中查询,否则直接执行大模型节点
def router(state:OverAllState) -> Literal["check_preference_node","llm_node"]:
    if not state.get("preferences"):
        logger.info("需要从长期记忆中读取用户偏好")
        return "check_preference_node"
    logger.info("用户偏好已经存在,不需要查询")
    return "llm_node"

#2.2 检查长期记忆节点
def check_preference_node(state:OverAllState,runtime:Runtime) -> OverAllState:
    #1. 拼接命名空间
    username = state["username"]
    namespace = (*USERS_NS,username)
    key = PREFERENCES_KEY
    #2. 获取长期记忆数据
    run_store = runtime.store
    run_item = run_store.get(namespace,key)

    if not item:
        logger.warning("长期记忆中没有{}的偏好数据",username)
        return {}

    logger.info("长期记忆中保存的{}的偏好数据是{}",username,run_item.value)
    return {
        "preferences":item.value
    }

def llm_node(state:OverAllState) -> OverAllState:
    # 检查是否存在长期记忆
    preference = state.get("preferences",{})
    user_input = state["user_input"]
    human_prompt = (f"这是用户的偏好: {preference}\n,这是用户的需求:{user_input}")
    system_prompt = "请根据用户的偏好解决用户的需求"

    messages: list[SystemMessage|HumanMessage|AIMessage|ToolMessage] = [SystemMessage(content=system_prompt)] if not state.get("messages",[]) else state["messages"]

    model_response = model.invoke(messages + [HumanMessage(content=human_prompt)])

    output = model_response.content

    return {
        "messages":messages+[HumanMessage(content=human_prompt),model_response],
        "output":output
    }

#3. 构建图
builder = StateGraph(state_schema=OverAllState)
builder.add_node("check_preference_node",check_preference_node)
builder.add_node("llm_node",llm_node)

builder.add_conditional_edges(START,router,path_map=["check_preference_node","llm_node"])
builder.add_edge("check_preference_node","llm_node")
builder.add_edge("llm_node",END)

#4. 构建长期记忆和短期记忆
with PostgresStore.from_conn_string(DB_URL) as store,\
    PostgresSaver.from_conn_string(DB_URL) as checkpointer :
    # 幂等操作  多次执行不会重新创建表格 不会删除数据库中的数据
    checkpointer.setup()
    graph = builder.compile(checkpointer=checkpointer,store=store)

    from IPython.display import display
    display(graph)

    config = {
        "configurable":{"thread_id":"777"}
    }

    res = graph.invoke({"username":"Alice","user_input":"我有点无聊,和我聊聊天吧"},config=config)

    print('=' * 50)
    print(res)

    res1 = graph.invoke({"username":"Alice","user_input":"推荐一下酸奶"},config=config)

    print('=' * 50)
    print(res1)
# Out:
# 2026-07-09 17:05:08.772 | INFO     | __main__:router:36 - 用户偏好已经存在,不需要查询
# 2026-07-09 17:05:16.346 | INFO     | __main__:router:36 - 用户偏好已经存在,不需要查询
# ==================================================
# {'messages': [SystemMessage(content='请根据用户的偏好解决用户的需求', additional_kwargs={}, response_metadata={}, id='6b9ba12c-9910-4d6a-ad03-2b1cacff1475'), HumanMessage(content="这是用户的偏好: {'food': '紫光园奶皮子酸奶', 'course': '计算机组成原理', 'sports': '跑步'}\n,这是用户的需求:我有点无聊,和我聊聊天吧", additional_kwargs={}, response_metadata={}, id='97c1ec4f-97f0-494f-a097-2fb0c36940bb'), AIMessage(content='嘿！既然你提到了，那我可得好好聊聊你喜欢的那些事～😄\n\n你爱吃的**紫光园奶皮子酸奶**，是不是那种口感浓稠、奶香满满的？我听说有人为了这一口专门跑去排队，感觉你也是个懂吃的人啊！要是现在来一杯，配点坚果或者蜂蜜，简直绝了。你一般什么时候会来一杯？当早餐还是下午解馋？\n\n再说说你学的**计算机组成原理**，这门课可真是“硬核中的硬核”——指令流水线、Cache、CPU设计……学起来有时候挺烧脑的吧？不过如果能搞懂冯·诺依曼架构和哈佛结构的区别，或者自己用Verilog搭一个简单CPU，那种成就感肯定很爽！你现在是在做实验、准备考试，还是单纯喜欢计算机底层的逻辑之美？\n\n最后，你选的运动是**跑步**，这个太棒了！是喜欢晨跑看日出，还是夜跑听歌放空？有没有特别喜欢的跑步路线，或者最近在练什么配速？我记得跑完步后，如果再来一杯紫光园的酸奶，简直是幸福双重奏啊！🏃\u200d♂️🥛\n\n所以……今天是想聊聊酸奶的N种吃法，还是吐槽CPU里的冒险？还是单纯想找个搭子一起云跑步？😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 275, 'prompt_tokens': 55, 'total_tokens': 330, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 55}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'dc52f242-301e-4319-83b6-46b34063bd9d', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f461e-57d2-7e00-98e9-a664641f01aa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 55, 'output_tokens': 275, 'total_tokens': 330, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content="这是用户的偏好: {'food': '紫光园奶皮子酸奶', 'course': '计算机组成原理', 'sports': '跑步'}\n,这是用户的需求:我有点无聊,和我聊聊天吧", additional_kwargs={}, response_metadata={}, id='c2bc200d-d6f6-4712-bbc7-793e09dcc181'), AIMessage(content='哈哈，看来你也是个“宝藏生活家”——冰火两重天的组合：**硬核的CPU逻辑** + **软乎乎的酸奶** + **酣畅淋漓的奔跑**。聊这几样，我可有100种姿势接话！😂\n\n顺着你抛出的话题，我来抛几个“聊点炸弹”：\n\n1️⃣ **关于那杯酸奶**：  \n   紫光园的奶皮子酸奶是不是有点像“酸奶界的舒芙蕾”？表面那层厚奶皮，据说要用勺子小心翼翼揭开才过瘾。我猜你吃的时候肯定有自己的“仪式感”——是先把奶皮刮干净吃掉，还是连奶皮带酸奶一口闷？要不要试试新吃法：把酸奶冻成冰淇淋口感，再撒点冻干草莓脆？（听起来热量有点危险，但快乐加倍！）\n\n2️⃣ **关于计组这门硬课**：  \n   要是把计算机组成原理和酸奶结合起来——假设你是个CPU设计师，会怎么设计一台“酸奶专供处理器”？要不要加入一条**MULT (Milk Ultra-Luscious Taste)** 指令？或者把Cache的替换策略改名为“喝完再换”（LRU）和“先喝旧的”（FIFO）？如果计组老师知道这个概念，估计会当场沉默然后给你加分🧠\n\n3️⃣ **关于跑步**：  \n   既然你爱跑步，又学计组……是不是经常幻想自己脑子里有一个**“步频控制器”** + **“心率调节器”**？跑得太喘的时候，给自己加一条NOP指令（空操作），放慢节奏缓一缓；冲刺的时候给自己执行一个“流水线加速模式”（超频跑）。要是跑步APP能显示“今日CPI（每步指令数）”和“Cache命中率（没崴脚率）”就神作了！😂\n\n**来，选一个：**  \n- A. 聊“酸奶的365种搭配方案”  \n- B. 编一个“用计组术语吐槽跑步”的鬼畜段子  \n- C. 其他？你开个头，我随时接梗！', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 435, 'prompt_tokens': 378, 'total_tokens': 813, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 378}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'f5bb7cb5-c264-4fff-9ec2-481baf01ef5d', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f461f-acaa-7f81-b9f6-23a2cdfe0d01-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 378, 'output_tokens': 435, 'total_tokens': 813, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})], 'username': 'Alice', 'user_input': '我有点无聊,和我聊聊天吧', 'output': '哈哈，看来你也是个“宝藏生活家”——冰火两重天的组合：**硬核的CPU逻辑** + **软乎乎的酸奶** + **酣畅淋漓的奔跑**。聊这几样，我可有100种姿势接话！😂\n\n顺着你抛出的话题，我来抛几个“聊点炸弹”：\n\n1️⃣ **关于那杯酸奶**：  \n   紫光园的奶皮子酸奶是不是有点像“酸奶界的舒芙蕾”？表面那层厚奶皮，据说要用勺子小心翼翼揭开才过瘾。我猜你吃的时候肯定有自己的“仪式感”——是先把奶皮刮干净吃掉，还是连奶皮带酸奶一口闷？要不要试试新吃法：把酸奶冻成冰淇淋口感，再撒点冻干草莓脆？（听起来热量有点危险，但快乐加倍！）\n\n2️⃣ **关于计组这门硬课**：  \n   要是把计算机组成原理和酸奶结合起来——假设你是个CPU设计师，会怎么设计一台“酸奶专供处理器”？要不要加入一条**MULT (Milk Ultra-Luscious Taste)** 指令？或者把Cache的替换策略改名为“喝完再换”（LRU）和“先喝旧的”（FIFO）？如果计组老师知道这个概念，估计会当场沉默然后给你加分🧠\n\n3️⃣ **关于跑步**：  \n   既然你爱跑步，又学计组……是不是经常幻想自己脑子里有一个**“步频控制器”** + **“心率调节器”**？跑得太喘的时候，给自己加一条NOP指令（空操作），放慢节奏缓一缓；冲刺的时候给自己执行一个“流水线加速模式”（超频跑）。要是跑步A ...
# ==================================================
# {'messages': [SystemMessage(content='请根据用户的偏好解决用户的需求', additional_kwargs={}, response_metadata={}, id='6b9ba12c-9910-4d6a-ad03-2b1cacff1475'), HumanMessage(content="这是用户的偏好: {'food': '紫光园奶皮子酸奶', 'course': '计算机组成原理', 'sports': '跑步'}\n,这是用户的需求:我有点无聊,和我聊聊天吧", additional_kwargs={}, response_metadata={}, id='97c1ec4f-97f0-494f-a097-2fb0c36940bb'), AIMessage(content='嘿！既然你提到了，那我可得好好聊聊你喜欢的那些事～😄\n\n你爱吃的**紫光园奶皮子酸奶**，是不是那种口感浓稠、奶香满满的？我听说有人为了这一口专门跑去排队，感觉你也是个懂吃的人啊！要是现在来一杯，配点坚果或者蜂蜜，简直绝了。你一般什么时候会来一杯？当早餐还是下午解馋？\n\n再说说你学的**计算机组成原理**，这门课可真是“硬核中的硬核”——指令流水线、Cache、CPU设计……学起来有时候挺烧脑的吧？不过如果能搞懂冯·诺依曼架构和哈佛结构的区别，或者自己用Verilog搭一个简单CPU，那种成就感肯定很爽！你现在是在做实验、准备考试，还是单纯喜欢计算机底层的逻辑之美？\n\n最后，你选的运动是**跑步**，这个太棒了！是喜欢晨跑看日出，还是夜跑听歌放空？有没有特别喜欢的跑步路线，或者最近在练什么配速？我记得跑完步后，如果再来一杯紫光园的酸奶，简直是幸福双重奏啊！🏃\u200d♂️🥛\n\n所以……今天是想聊聊酸奶的N种吃法，还是吐槽CPU里的冒险？还是单纯想找个搭子一起云跑步？😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 275, 'prompt_tokens': 55, 'total_tokens': 330, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 55}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'dc52f242-301e-4319-83b6-46b34063bd9d', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f461e-57d2-7e00-98e9-a664641f01aa-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 55, 'output_tokens': 275, 'total_tokens': 330, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content="这是用户的偏好: {'food': '紫光园奶皮子酸奶', 'course': '计算机组成原理', 'sports': '跑步'}\n,这是用户的需求:我有点无聊,和我聊聊天吧", additional_kwargs={}, response_metadata={}, id='c2bc200d-d6f6-4712-bbc7-793e09dcc181'), AIMessage(content='哈哈，看来你也是个“宝藏生活家”——冰火两重天的组合：**硬核的CPU逻辑** + **软乎乎的酸奶** + **酣畅淋漓的奔跑**。聊这几样，我可有100种姿势接话！😂\n\n顺着你抛出的话题，我来抛几个“聊点炸弹”：\n\n1️⃣ **关于那杯酸奶**：  \n   紫光园的奶皮子酸奶是不是有点像“酸奶界的舒芙蕾”？表面那层厚奶皮，据说要用勺子小心翼翼揭开才过瘾。我猜你吃的时候肯定有自己的“仪式感”——是先把奶皮刮干净吃掉，还是连奶皮带酸奶一口闷？要不要试试新吃法：把酸奶冻成冰淇淋口感，再撒点冻干草莓脆？（听起来热量有点危险，但快乐加倍！）\n\n2️⃣ **关于计组这门硬课**：  \n   要是把计算机组成原理和酸奶结合起来——假设你是个CPU设计师，会怎么设计一台“酸奶专供处理器”？要不要加入一条**MULT (Milk Ultra-Luscious Taste)** 指令？或者把Cache的替换策略改名为“喝完再换”（LRU）和“先喝旧的”（FIFO）？如果计组老师知道这个概念，估计会当场沉默然后给你加分🧠\n\n3️⃣ **关于跑步**：  \n   既然你爱跑步，又学计组……是不是经常幻想自己脑子里有一个**“步频控制器”** + **“心率调节器”**？跑得太喘的时候，给自己加一条NOP指令（空操作），放慢节奏缓一缓；冲刺的时候给自己执行一个“流水线加速模式”（超频跑）。要是跑步APP能显示“今日CPI（每步指令数）”和“Cache命中率（没崴脚率）”就神作了！😂\n\n**来，选一个：**  \n- A. 聊“酸奶的365种搭配方案”  \n- B. 编一个“用计组术语吐槽跑步”的鬼畜段子  \n- C. 其他？你开个头，我随时接梗！', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 435, 'prompt_tokens': 378, 'total_tokens': 813, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 378}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'f5bb7cb5-c264-4fff-9ec2-481baf01ef5d', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f461f-acaa-7f81-b9f6-23a2cdfe0d01-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 378, 'output_tokens': 435, 'total_tokens': 813, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content="这是用户的偏好: {'food': '紫光园奶皮子酸奶', 'course': '计算机组成原理', 'sports': '跑步'}\n,这是用户的需求:推荐一下酸奶", additional_kwargs={}, response_metadata={}, id='59337579-cf4c-43ff-9748-a1ccdc3f07de'), AIMessage(content='哈哈，既然点名要推荐酸奶，那我可要来一场 **“紫光园奶皮子酸奶与计算机组成原理的硬核联动”** 了！\n\n**第一杯：经典原味 —— 相当于CPU的“单核单线程”，稳如老狗！**  \n就是紫光园那款最基础的奶皮子酸奶，口感醇厚、奶香爆炸。表面那层奶皮就像CPU的**一级缓存（L1 Cache）**——最靠近“处理器”（你的嘴），访问速度（开吃）极快，延迟几乎为零。适合不想动脑子、只想体验纯粹快乐的时候来一杯。\n\n**第二杯：冻一下再吃 —— “流水线并行加速版”**  \n把紫光园奶皮子酸奶丢进冷冻室半小时，拿出来就变成半冰沙状态。吃的时候能同时体验脆奶皮+冰沙+软酸奶三种口感，相当于**超标量处理器**在一条指令流里并行处理多条指令（三种口感同时刺激味蕾）！适合学计组学到头秃时，给大脑一个“多级流水线Refresh”。\n\n**第三杯：酸奶+坚果/蜂蜜 —— 加了“协处理器”的增强版**  \n撒一把巴旦木或核桃碎，再淋点蜂蜜。坚果的脆和蜂蜜的甜相当于给酸奶配了个**GPU**（负责图形 ...
