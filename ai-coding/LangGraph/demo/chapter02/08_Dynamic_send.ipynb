# %%
"""
动态分支 - 并行节点
"""
from typing import TypedDict,Literal,Sequence
from wsgiref.util import request_uri

from IPython.core.debugger import prompt
from langchain_deepseek import ChatDeepSeek
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send
from langchain.messages import HumanMessage
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from rich import print as rprint
import os
from dotenv import load_dotenv
load_dotenv(override=True)

GEMINI_API_KEY=os.getenv("GEMINI_API_KEY")
GEMINI_BASE_URL=os.getenv("GEMINI_BASE_URL")

model = init_chat_model(
  model="gemini-2.5-flash",
  model_provider="google_genai",
  api_key=GEMINI_API_KEY,
  transport="rest"  # 强制使用 REST 协议
)

CONTENT_TYPES = ["poem","joke","ci_poem"]

#1. 定义状态
#1.1 全局状态
class OverAllState(TypedDict):
    topic: str
    poem: str
    ci_poem:str
    joke: str

#1.2 私有状态
class workerState(TypedDict):
    content_type: Literal["poem","joke","ci_poem"]
    prompt: str

#1.3 输入状态
class inputState(TypedDict):
    topic: str

#1.4 输出状态
class outputState(TypedDict):
    poem: str
    ci_poem:str
    joke: str

# 2. 定义节点
def worker_node(state:workerState) -> outputState:
    content_type = state["content_type"]
    prompt = state["prompt"]
    content = model.invoke([HumanMessage(prompt)]).content
    return {
        content_type: content
    }

#3. 定义动态分支的路由
# 核心体现点：1 次路由触发，同时产生 3 个独立的 Send 任务
def router(state:inputState) -> Sequence[Send]:
    router_prompt = "请生成关于{} 的 {}"
    english2Chinese = {
        "poem": "七言绝句",
        "joke": "笑话",
        "ci_poem": "中文词"
    }
    topic = state["topic"]
    return [
        Send(
            "worker_node",
            {
                "content_type": content_type,
                "prompt": router_prompt.format(topic, english2Chinese[content_type])
            }
        )
        for content_type in CONTENT_TYPES
    ]

#4. 构建图
builder = StateGraph(state_schema=OverAllState,input_schema=inputState,output_schema=outputState)

builder.add_node("worker_node", worker_node)
builder.add_conditional_edges(
    START,
    router,
    path_map=["worker_node"],
    )

builder.add_edge("worker_node",END)

graph = builder.compile()
res = graph.invoke({"topic": "莲花"})
rprint(res)

from IPython.display import display
display(graph)


raw_mermaid = graph.get_graph().draw_mermaid()
print(raw_mermaid)
# Out:
# {
#     'poem':
# '好的，为您生成三首关于莲花的七言绝句，各具侧重：\n\n---\n\n**第一首：赞其高洁**\n（侧重：出淤泥而不染的品格）\n\n
# 淤泥深处自生根，\n出水芙蓉不染尘。\n香远益清君子意，\n冰心玉洁世人尊。\n\n*   **释义：**\n    *
# 在深厚的淤泥中生根发芽，\n    *   却能亭亭玉立于水面之上，不沾染一丝尘埃。\n    *
# 它的清香传得很远，却愈发显得纯净，如同君子的品德。\n    *
# 它那冰清玉洁的品质，受到世人的敬重。\n\n---\n\n**第二首：描其风姿**\n（侧重：夏日荷塘的景致与生机）\n\n碧叶田田映日
# 红，\n粉苞初绽露华浓。\n蜻蜓点水舞翩跹，\n盛夏清凉入梦中。\n\n*   **释义：**\n    *
# 碧绿的荷叶一片片铺展开来，在阳光下映照出红色的光晕。\n    *   粉色的花苞初次绽放，凝聚着浓郁的露珠精华。\n    *
# 轻盈的蜻蜓在水面轻点，翩翩起舞。\n    *
# 带来盛夏时节的清凉，仿佛能进入人们的梦境。\n\n---\n\n**第三首：寓其禅意**\n（侧重：宁静、淡泊的意境）\n\n静水无波映
# 碧空，\n芙蓉亭亭立其中。\n不染尘嚣出污泥，\n独留清韵与风同。\n\n*   **释义：**\n    *
# 平静的水面没有一丝波澜，清晰地倒映着碧蓝的天空。\n    *   莲花（芙蓉）亭亭玉立，静静地矗立在水中。\n    *
# 它不被世俗的喧嚣所沾染，从污泥中超然生长。\n    *   独自保留着那份清雅的韵味，与清风相伴，超然物外。',
#     'ci_poem':
# "好的，关于莲花（Lotus）的中文词汇非常丰富，因为它在中国文化、文学和佛教中都有着极其重要的地位。以下为您整理：\n\n-
# --\n\n### 一、 莲花的通用名称 (General Names)\n\n1.  **莲花** (liánhuā): 最常见的名称，强调“花”本身。\n2.  **荷花**
# (héhuā): 也很常见，通常指整个莲科植物，包括叶、花、茎等。在日常生活中，莲花和荷花常混用。\n3.  **芙蓉** (fúróng):
# 古代常用来指荷花，尤其指其美丽。现代也指木芙蓉（hibiscus），需根据语境区分。\n4.  **芙蕖** (fúqú):
# 古代对荷花的雅称。\n5.  **菡萏** (hàndàn): 特指未开的荷花花苞。\n6.  **水芙蓉** (shuǐfúróng):
# 指水中的芙蓉，即荷花。\n7.  **泽芝** (zézhī): 古代别称。\n8.  **君子花** (jūnzǐhuā): 因其高洁的品格而得名。\n9.
# **睡莲** (shuìlián): 严格来说，睡莲是另一个属的植物，但因形态相似且同为水生，常被提及或混淆。\n\n---\n\n### 二、
# 莲花的各个部分 (Parts of the Lotus Plant)\n\n1.  **荷叶 / 莲叶** (héyè / liányè): 莲花的叶子。\n    *   **碧叶**
# (bìyè): 形容绿色的荷叶。\n    *   **翠盖** (cuìgài): 形容荷叶像翠绿的伞盖。\n2.  **荷梗 / 莲梗** (hégěng /
# liángěng): 莲花的茎。\n3.  **莲蓬** (liánpéng): 莲花结实后的花托，上面布满莲子。\n4.  **莲子** (liánzǐ):
# 莲花的种子，可食用。\n    *   **莲子心** (liánzǐxīn): 莲子中间的绿色胚芽，味苦，有清热功效。\n5.  **莲藕**
# (lián'ǒu): 莲花的地下茎，肥大中空，可食用。\n    *   **藕断丝连** (ǒuduànsīlián):
# 藕折断了，但藕丝还连着。比喻表面断绝关系，实际仍有牵连。\n6.  **花瓣** (huābàn): 莲花的花瓣。\n7.  **花蕊**
# (huāruǐ): 莲花的花蕊。\n8.  **花苞** (huābāo): 莲花未开的花蕾，同“菡萏”。\n\n---\n\n### 三、 形容莲花的词语
# (Descriptive Terms for Lotus)\n\n1.  **清香** (qīngxiāng): 清淡的香气。\n2.  **芬芳** (fēnfāng): 浓郁的香气。\n3.
# **洁白** (jiébái): 纯洁的白色。\n4.  **粉红** (fěnhóng): 浅粉色。\n5.  **亭亭玉立** (tíngtíngyùlì):
# 形容莲花姿态优美，高雅挺拔。\n6.  **婀娜多姿** (ēnáduōzī): 形容姿态柔美，变化多样。\n7.  **冰清玉洁**
# (bīngqīngyùjié): 形容品德高尚，像冰一样清澈，像玉一样纯洁。\n8.  **出水芙蓉** (chūshuǐfúróng):
# 形容女子娇柔美丽，也比喻诗文清新自然。\n9.  **清新脱俗** (qīngxīntuōsú): 清新而不落俗套。\n\n---\n\n### 四、
# 莲花的文化与象征意义 (Cultural & Symbolic Meanings)\n\n1.  **纯洁** (chúnjié): 因其“出淤泥而不染”的特性。\n2.
# **高洁** (gāojié): 品德高尚，纯洁无瑕。\n3.  **清廉** (qīnglián): 象征官员清正廉洁。\n4.  **君子** (jūnzǐ):
# 比喻品德高尚的人。\n5.  **佛教** (fójiào): 莲花在佛教中是神圣的象征，代表纯净、智慧和解脱。\n    *   **莲座**
# (liánzuò): 佛像所坐的莲花宝座。\n    *   **莲花宝座** (liánhuābǎozuò): 同上，更强调其尊贵。\n    *
# **西方极乐世界** (xīfāngjílèshìjiè): 佛教中阿弥陀佛的净土，以莲花为主要景象。\n6.  **并蒂莲** (bìngdìlián):
# 两朵莲花共用一个花梗，象征夫妻恩爱、永结同心。\n7.  **连年有余** (liánniányǒuyú):
# “莲”与“连”谐音，“鱼”与“余”谐音，寓意生活富足，年年都有剩余。\n\n---\n\n### 五、 常见搭配与短语 (Common Collocations
# & Phrases)\n\n1.  **观荷 / 赏荷** (guānhé / shǎnghé): 观赏荷花。\n2.  **荷塘月色** (hétángyuèsè):
# 月光下的荷塘，出自朱自清的散文名篇。\n3.  **荷风送香** (héfēngsòngxiāng): 荷花的香气随风飘送。\n4.  **莲藕排骨汤**
# (lián'ǒu páigǔtāng): 一道经典的家常菜。\n5.  **莲子羹** (liánzǐgēng): 以莲子为主料的甜品。\n6.  **荷叶饭**
# (héyèfàn): 用荷叶包裹蒸煮的米饭。\n7.  **出淤泥而不染，濯清涟而不妖** (chūyūní'érbùrǎn, zhuóqīnglián'érbùyāo):
# 出自周敦颐的《爱莲说》，意为从污泥中生长出来却不被沾染，在清水中洗涤却不显得妖媚，形容莲花的高洁品格。\n\n---\n\n希
# 望这份详尽的词汇表能帮助您更好地理解和使用关于莲花的中文表达！",
#     'joke': '好的，这里有几个关于莲花的笑话：\n\n1.  **为什么莲花从不抱怨自己的出身？**\n
# 因为它知道，越是“出淤泥”，就越能“不染”！\n\n2.  **莲花在池塘里照镜子，突然大叫一声：“天啊！”**\n
# 它发现自己不是“出淤泥而不染”，而是……“出淤泥而美颜了！”\n\n3.  **一个莲蓬对旁边的莲花说：“你真是太幸运了！”**\n
# 莲花问：“为什么？”\n    莲蓬叹了口气：“因为你只负责美，我还要负责生孩子（莲子）！”\n\n4.
# **老师问小莲花：“你最擅长什么瑜伽姿势？”**\n    小莲花骄傲地挺起胸膛：“当然是莲花坐！我可是天生的！”\n\n5.
# **为什么莲花从来不参加“下沉挑战”？**\n    因为它知道，它这辈子注定是要“浮”起来的！\n\n希望这些能让你笑一笑！'
# }
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	worker_node(worker_node)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ -.-> worker_node;
# 	worker_node --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
