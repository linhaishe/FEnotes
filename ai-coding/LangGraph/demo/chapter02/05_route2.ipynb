# %%
"""
同时路由到多个节点 W/ path map
"""

from typing import TypedDict,Literal,Sequence
from langgraph.graph import StateGraph, START, END
from langchain.chat_models import init_chat_model
from rich import print as rprint
import os

from dotenv import load_dotenv
load_dotenv(override=True)

GEMINI_API_KEY=os.getenv("GEMINI_API_KEY")
GEMINI_BASE_URL=os.getenv("GEMINI_BASE_URL")

model = init_chat_model(
  model="gemini-2.5-flash",
  model_provider="google_genai",
  api_key=GEMINI_API_KEY,
  transport="rest"  # 强制使用 REST 协议
)


#1. 定义状态
class OverAllState(TypedDict):
    topic: str
    poem: str
    joke: str
    ci_poem:str
    content_type: str

#2. 定义节点
def node_a(state: OverAllState) -> OverAllState:
    poem = model.invoke([f"写一首关于{state['topic']}主题的诗"]).content
    return {
        "poem": poem
    }

def node_b(state: OverAllState) -> OverAllState:
    joke = model.invoke([f"写一个关于{state['topic']}主题的笑话"]).content
    return {
        "joke": joke
    }

def node_c(state: OverAllState) -> OverAllState:
    ci_poem = model.invoke([f"写一首关于{state['topic']}主题的词"]).content
    return {
        "ci_poem": ci_poem
    }

def my_route(state: OverAllState) -> Sequence[Literal["node_a","node_b","node_c"]]:
    if "诗" in state["content_type"]:
        return ["node_a","node_c"]
    else:
        return ["node_b","node_c"]


#3. 构建图
builder = StateGraph(state_schema=OverAllState)
builder.add_node(node_a)
builder.add_node(node_b)
builder.add_node(node_c)

builder.add_conditional_edges(START,my_route)
builder.add_edge("node_b",END)
builder.add_edge("node_a",END)
builder.add_edge("node_c",END)

graph = builder.compile()
poem_res = graph.invoke({"topic": "猫咪","content_type":"诗"})
rprint(poem_res)

joke_res = graph.invoke({"topic": "猫咪","content_type":"笑话"})
rprint(joke_res)

from IPython.display import display
display(graph)

raw_mermaid = graph.get_graph().draw_mermaid()
print(raw_mermaid)
# Out:
# {
#     'topic': '猫咪',
#     'poem':
# '好的，这是一首关于猫咪的诗：\n\n**猫之歌**\n\n一身绒毛软如云，\n步履轻盈悄无声。\n琥珀眼眸藏灵韵，\n静观世事总从容
# 。\n\n阳光暖照伸懒腰，\n忽而追逐光影摇。\n腾挪扑跃身姿巧，\n一尾轻甩自逍遥。\n\n炉火旁畔暖意浓，\n膝上蜷卧入梦中。\
# n轻声咕噜细语哝，\n岁月静好与君同。\n\n有时依偎蹭我手，\n有时独立不回头。\n眼中深藏古老咒，\n看透尘世几多愁。\n\n它
# 来它去总无言，\n却把温柔撒人间。\n有它相伴岁月甜，\n一幅诗意画卷添。',
#     'ci_poem': '好的，为您写一首以猫咪为主题的《蝶恋花》：\n\n**蝶恋花 ·
# 慵猫**\n\n日暖窗台慵卧处，\n绒毛细软，碧眼凝光。\n忽而伸腰倦懒态，\n喉间轻响，梦入寻常。\n\n又见轻身扑蝶影，\n穿梭
# 花间，步履无声。\n性本疏狂，偶也娇嗔，\n清欢半盏，共度晨昏。\n\n---\n\n**赏析：**\n\n*   **上阕**
# 描绘了猫咪安静、慵懒的一面。\n    *
# “日暖窗台慵卧处”：点明了猫咪最爱的栖息地——阳光充足的窗台，以及它经典的慵懒姿态。\n    *
# “绒毛细软，碧眼凝光”：细致描绘了猫咪的外貌特征，柔软的毛发和充满神采的眼睛，极具画面感。\n    *
# “忽而伸腰倦懒态”：捕捉了猫咪从睡梦中醒来，舒展身体的招牌动作，一个“倦懒”字将神态写活。\n    *
# “喉间轻响，梦入寻常”：暗示了猫咪满足时的“咕噜”声，将其视为融入日常、带来宁静的梦境，充满诗意。\n\n*   **下阕**
# 展现了猫咪活泼、独立又带点娇憨的另一面。\n    *
# “又见轻身扑蝶影”：转而写猫咪的动态，轻盈的身姿追逐飞舞的蝴蝶影子，充满玩趣。\n    *
# “穿梭花间，步履无声”：进一步描写其敏捷和隐秘，穿行于花丛中，脚步轻巧得听不到声音，符合猫咪的狩猎本能。\n    *
# “性本疏狂，偶也娇嗔”：这是对猫咪性格的深刻描摹。它天性独立、自由散漫（疏狂），但偶尔也会向主人撒娇卖萌（娇嗔），展
# 现出其复杂而迷人的个性。\n    *
# “清欢半盏，共度晨昏”：点明了猫咪与主人之间的情感连接。它不求大富大贵，只带来一份简单而纯粹的快乐（清欢），默默地陪
# 伴主人度过每一个日夜，是生活中不可或缺的温柔存在。',
#     'content_type': '诗'
# }
# {
#     'topic': '猫咪',
#     'joke': '好的，来一个猫咪主题的笑话：\n\n**问：** 为什么猫咪总是那么高傲，好像自己是家里的老大？\n\n**答：**
# 因为它们觉得，人类是它们雇来铲屎和喂饭的员工啊！',
#     'ci_poem': '好的，这里为您写一首以猫咪为主题的《蝶恋花》词。\n\n---\n\n**蝶恋花 ·
# 慵猫**\n\n绒毛细软卧榻旁，\n慵卧窗台日影长。\n碧瞳半阖，梦里捕蝶忙，\n偶抬小爪挠痒痒。\n\n忽闻细响精神振，\n弓身如
# 电掠微尘。\n捕捉光影，爪尖带露痕，\n一室温馨有此君。\n\n---\n\n**赏析：**\n\n*   **词牌：**
# 《蝶恋花》，此词牌格律平仄严谨，上下阕各四句，通常前三句押韵，末句换韵。这里采用上下阕各押一韵的写法（上阕：旁、长
# 、忙、痒；下阕：振、尘、痕、君）。\n*   **上阕（描绘静态与梦境）：**\n    *
# “绒毛细软卧榻旁，慵卧窗台日影长。”：开篇点明猫咪柔软的毛发和它慵懒地卧在窗台边的姿态，阳光拉长了它的身影，营造出宁
# 静、温暖的画面。\n    *
# “碧瞳半阖，梦里捕蝶忙。”：写猫咪半闭的碧绿色眼睛，暗示它似睡非睡，或在梦中延续着捕猎的本能，将猫咪的静态与内在的活
# 力结合。\n    *   “偶抬小爪挠痒痒。”：一个非常生动、充满生活气息的细节，展现了猫咪可爱、真实的习性。\n*
# **下阕（描绘动态与陪伴）：**\n    *
# “忽闻细响精神振。”：笔锋一转，写猫咪听到细微声响后，瞬间警觉，精神抖擞，展现其敏锐的听觉和快速的反应。\n    *
# “弓身如电掠微尘。”：形容猫咪弓起身子，像闪电般迅速地扑向目标，即使是细微的灰尘也逃不过它的“狩猎”，突出了它的矫健和
# 敏捷。\n    *
# “捕捉光影，爪尖带露痕。”：进一步刻画猫咪玩耍的场景，它追逐着光影，爪尖似乎带着露珠般的湿润或轻巧，富有诗意。\n    *
# “一室温馨有此君。”：结尾点睛，总结猫咪在家中的存在感，它不仅是宠物，更是为居室带来温馨和活力的“君子”，表达了对猫咪
# 的喜爱和依赖。\n\n整首词通过动静结合、细节描绘，将猫咪慵懒、可爱、敏捷、灵动的形象跃然纸上，字里行间流露出对猫咪的
# 喜爱之情。',
#     'content_type': '笑话'
# }
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__(<p>__start__</p>)
# 	node_a(node_a)
# 	node_b(node_b)
# 	node_c(node_c)
# 	__end__(<p>__end__</p>)
# 	__start__ -.-> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
