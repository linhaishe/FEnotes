# %%
"""
同时路由到多个节点 W path map
"""

from typing import TypedDict,Literal,Sequence
from langgraph.graph import StateGraph, START, END
from langgraph.graph import StateGraph, START, END
from langchain.chat_models import init_chat_model
from rich import print as rprint
import os

from dotenv import load_dotenv
load_dotenv(override=True)

GEMINI_API_KEY=os.getenv("GEMINI_API_KEY")
GEMINI_BASE_URL=os.getenv("GEMINI_BASE_URL")

model = init_chat_model(
  model="gemini-2.5-flash",
  model_provider="google_genai",
  api_key=GEMINI_API_KEY,
  transport="rest"  # 强制使用 REST 协议
)

#1. 定义状态
class OverAllState(TypedDict):
    topic: str
    poem: str
    joke: str
    ci_poem:str
    content_type: str

#2. 定义节点
def node_a(state: OverAllState) -> OverAllState:
    poem = model.invoke([f"写一首关于{state['topic']}主题的诗"]).content
    return {
        "poem": poem
    }

def node_b(state: OverAllState) -> OverAllState:
    joke = model.invoke([f"写一个关于{state['topic']}主题的笑话"]).content
    return {
        "joke": joke
    }

def node_c(state: OverAllState) -> OverAllState:
    ci_poem = model.invoke([f"写一首关于{state['topic']}主题的词"]).content
    return {
        "ci_poem": ci_poem
    }

def my_route(state: OverAllState) -> Sequence[Literal["poem","joke","ci_poem"]]:
    if "诗" in state["content_type"]:
        return ["poem","ci_poem"]
    else:
        return ["joke","ci_poem"]


#3. 构建图
builder = StateGraph(state_schema=OverAllState)
builder.add_node(node_a)
builder.add_node(node_b)
builder.add_node(node_c)

builder.add_conditional_edges(
    START,
    my_route,
    path_map={
        "poem": "node_a",
        "joke": "node_b",
        "ci_poem": "node_c",
    }
)
builder.add_edge("node_b",END)
builder.add_edge("node_a",END)
builder.add_edge("node_c",END)

graph = builder.compile()
poem_res = graph.invoke({"topic": "猫咪","content_type":"诗"})
rprint(poem_res)

joke_res = graph.invoke({"topic": "猫咪","content_type":"笑话"})
rprint(joke_res)

from IPython.display import display
display(graph)

raw_mermaid = graph.get_graph().draw_mermaid()
print(raw_mermaid)
# Out:
# {
#     'topic': '猫咪',
#     'poem':
# '当然，为你奉上一首关于猫咪的诗：\n\n**猫之歌**\n\n一身软绒衣，步履悄无声，\n小巧的身影，穿梭于光影。\n眼眸似琥珀，
# 深邃藏古意，\n时而狭长如线，映着窗外风景。\n\n晨光洒在地，它蜷成一团，\n在暖阳里沉睡，做着甜甜的梦。\n偶尔抖动耳尖
# ，捕捉细微声响，\n是警惕的本能，也是慵懒的从容。\n\n伸个懒腰，姿态优雅舒展，\n弓背如弦月，爪尖轻触地面。\n忽而跳跃
# ，追逐光点嬉戏，\n毛线球滚动，是它最好的玩伴。\n\n喉间轻颤，咕噜咕噜低语，\n那是满足的歌，是对世界的温柔。\n蹭着主
# 人的腿，表达无声的依恋，\n亦是独立的灵魂，不被任何束缚。\n\n它是家中的精灵，神秘而美丽，\n是静默的陪伴，是无言的诗
# 句。\n在它的眼中，世界简单而纯粹，\n一只猫，便是一整个宇宙的奇迹。',
#     'ci_poem':
# '好的，为您写一首以猫咪为主题的词。我们选用词牌《浣溪沙》。\n\n**《浣溪沙·猫》**\n\n软卧晴窗日影长，\n琥珀瞳眸映暖
# 阳，\n轻声咕噜入梦乡。\n\n忽而探爪扑流萤，\n矫健身姿跃半空，\n又来依偎伴烛红。\n尘世何须问西东。\n\n---\n\n**赏析：
# **\n\n*   **上阕：**\n    *
# "软卧晴窗日影长"：描绘猫咪慵懒地躺在洒满阳光的窗台上，享受着悠长的日光浴，画面宁静而美好。\n    *
# "琥珀瞳眸映暖阳"：点出猫咪的眼睛，用“琥珀”形容其色泽与光芒，透出温暖与神秘，与“暖阳”相映成趣。\n    *
# "轻声咕噜入梦乡"：捕捉猫咪特有的“咕噜”声，这是它们满足和舒适的标志，暗示它已进入甜美的梦境，也传递出一种安宁的氛围
# 。\n\n*   **下阕：**\n    *
# "忽而探爪扑流萤"：笔锋一转，展现猫咪活泼、调皮的一面。它突然伸出爪子捕捉飞舞的萤火虫（或泛指任何小飞虫），动感十足
# 。\n    *   "矫健身姿跃半空"：进一步描绘猫咪敏捷的身手和优雅的姿态，无论是跳跃还是扑腾，都充满力量与美感。\n    *
# "又来依偎伴烛红"：动静结合，玩耍过后，猫咪又回到主人身边，依偎在烛光旁，展现它温顺和亲近的一面，营造出温馨的夜晚景
# 象。\n    *
# "尘世何须问西东"：这是全词的点睛之笔。猫咪的生活简单纯粹，活在当下，不为世俗烦恼所困。这句是对猫咪生活哲学的提炼，
# 也寄托了词人对这种超然态度的向往。\n\n整首词通过对猫咪外形、动作、习性以及其与人互动场景的描绘，展现了猫咪慵懒、神
# 秘、活泼、亲昵等多重魅力，并借由猫咪的形象，表达了一种超脱世俗、活在当下的生活态度。',
#     'content_type': '诗'
# }
# {
#     'topic': '猫咪',
#     'joke':
# '好的，这是一个关于猫咪的笑话：\n\n为什么猫咪总是看起来很忙？\n因为它在努力思考，如何用最优雅的方式把桌上的东西推下
# 去！',
#     'ci_poem': '好的，为您写一首以猫咪为主题的《蝶恋花》词。\n\n**蝶恋花 ·
# 咏猫**\n\n暖日融融小窗畔，一团绒。\n琥珀金瞳微半阖，倦意浓。\n轻舒玉爪无声处，姿态从容。\n舔毛理鬓纤纤细，意态玲珑
# 。\n\n忽而扑蝶弄花影，身姿轻。\n跳跃矫健身如电，眼含星。\n咕噜轻声偎人畔，暖意盈。\n添得夜阑消寂寞，伴书灯。\n世间
# 浮华皆过眼，唯此情。\n\n---\n\n**解释：**\n\n*
# **词牌名：《蝶恋花》**，是宋词中常用的一个词牌，通常为双调，上下两阕，共六十字。\n*   **上阕
# (描写猫咪安静、慵懒的一面)：**\n    *
# “暖日融融小窗畔，一团绒。”：描绘猫咪在温暖阳光下，蜷缩成一团毛茸茸的样子。\n    *
# “琥珀金瞳微半阖，倦意浓。”：形容猫咪半开的眼睛，像琥珀或金色宝石，带着浓浓的倦怠和慵懒。\n    *
# “轻舒玉爪无声处，姿态从容。”：写猫咪伸展身体时，柔软的爪子悄无声息，举止优雅从容。\n    *
# “舔毛理鬓纤纤细，意态玲珑。”：描写猫咪细致地梳理毛发，动作轻巧，姿态灵动可爱。\n*   **下阕
# (描写猫咪活泼、陪伴的一面)：**\n    *
# “忽而扑蝶弄花影，身姿轻。”：笔锋一转，写猫咪突然变得活泼，追逐蝴蝶或花影，身形轻盈。\n    *
# “跳跃矫健身如电，眼含星。”：形容猫咪跳跃时矫健敏捷，像闪电一般，眼睛里闪烁着光芒（如星辰）。\n    *
# “咕噜轻声偎人畔，暖意盈。”：写猫咪撒娇时发出轻柔的“咕噜”声，依偎在人身边，带来满满的温暖。\n    *
# “添得夜阑消寂寞，伴书灯。”：猫咪在深夜陪伴主人，消解寂寞，在书灯旁静静相伴。\n    *
# “世间浮华皆过眼，唯此情。”：点出主旨，世间繁华喧嚣都如过眼云烟，唯有这份与猫咪相伴的温情和宁静才是最珍贵的。\n\n这
# 首词通过对猫咪不同姿态和行为的描绘，展现了猫咪的慵懒、优雅、活泼与陪伴，表达了对猫咪的喜爱和它所带来的心灵慰藉。',
#     'content_type': '笑话'
# }
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	node_a(node_a)
# 	node_b(node_b)
# 	node_c(node_c)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ -. &nbsp;poem&nbsp; .-> node_a;
# 	__start__ -. &nbsp;joke&nbsp; .-> node_b;
# 	__start__ -. &nbsp;ci_poem&nbsp; .-> node_c;
# 	node_a --> __end__;
# 	node_b --> __end__;
# 	node_c --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
from typing import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain.messages import HumanMessage
from langchain_deepseek import ChatDeepSeek
from loguru import logger

from dotenv import load_dotenv

load_dotenv(override=True)

model = ChatDeepSeek(
    model="deepseek-v4-flash",
    extra_body={
        "thinking": {
            "type": "disabled"
        }
    }
)

class OverAllState(TypedDict):
    topic: str
    poem: str
    joke: str

def node_a(state: OverAllState) -> OverAllState:
    poem = model.invoke([HumanMessage(f"写一首关于 {state['topic']} 的七言绝句")]).content

    return {
        "poem": poem
    }

def node_b(state: OverAllState) -> OverAllState:
    joke = model.invoke([HumanMessage(f"写一个关于 {state['topic']} 的笑话")]).content

    return {
        "joke": joke
    }

def audit_node(state: OverAllState) -> OverAllState:
    logger.info(f"任务节点全部执行完毕，诗 {'已生成' if state['poem'] else '未生成'}，笑话 {'已生成' if state['joke'] else '未生成'}")

builder = StateGraph(state_schema=OverAllState)
builder.add_node("node_a", node_a)
builder.add_node("node_b", node_b)
builder.add_node("audit_node", audit_node, defer=True)
builder.add_edge(START, "node_a")
builder.add_edge(START, "node_b")
builder.add_edge(START, "audit_node")
builder.add_edge("node_a", END)
builder.add_edge("node_b", END)
builder.add_edge("audit_node", END)

graph = builder.compile()
res = graph.invoke({"topic": "布偶狗"})
print(res)

from IPython.display import display

display(graph)
